# %% [markdown]
# # Analisis exploratorio CHURN

# %% [markdown]
# # Intrucciones
# 15 funciones de Probabilidad y Estadística, aplicadas al problema de Churn sobre el dataset que estamos trabajando.
#
# No todos los integrantes tienen que responder la pregunta.
#
# Formato de entrega:
# 1. La pregunta que busco contestar, usando términos de Probabilidad y Estadística.
# 2. El código que responde a dicha pregunta, junto con la salida de dicho código.
# 3. La respuesta (su interpretación) a dicho código.
#
# ### ejemplo
# ![image.png](attachment:image.png)
#
# # el repositorio con codigo de ayuda
# https://github.com/robertoarturomc/MetodosEstadisticos/blob/main/2_Reto_Modelado_Estadistico.ipynb
